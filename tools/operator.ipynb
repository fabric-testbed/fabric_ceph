# %%
import ceph_subvol_gui as gui

gui.DEFAULT_CEPH_API_BASE = "https://ceph-mgr.fabric-testbed.net"
gui.DEFAULT_REPORTS_API_BASE = "https://reports.fabric-testbed.net/reports"
gui.DEFAULT_CORE_API_BASE = "https://uis.fabric-testbed.net"
gui.DEFAULT_VERIFY_TLS = False
gui.DEFAULT_CEPHFS_VOLUME = "CEPH-FS-01"
gui.DEFAULT_CLUSTER = "east"
gui.DEFAULT_TOKEN_FILE = "/Users/kthare10/work/fabric_config/id_token.json"

from ceph_subvol_gui import launch
launch()
